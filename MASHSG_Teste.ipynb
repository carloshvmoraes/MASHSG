# %%
# !wget https://raw.githubusercontent.com/carloshvmoraes/MASHSG/main/src/mashsg.py?token=GHSAT0AAAAAABP4N36HRLUULQ4RH4TJPBCKYPPLOSA -O mashsg.py
# !wget https://raw.githubusercontent.com/carloshvmoraes/MASHSG/main/sample/Circuito01.json?token=GHSAT0AAAAAABP4N36G2KLCPCHO7XRP5AQMYPPLRCA -O Circuito01.json
# Out:
# --2022-01-25 02:10:39--  https://raw.githubusercontent.com/carloshvmoraes/MASHSG/main/src/mashsg.py?token=GHSAT0AAAAAABP4N36HRLUULQ4RH4TJPBCKYPPLOSA
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 17739 (17K) [text/plain]
# Saving to: ‘mashsg.py’
#
# mashsg.py           100%[===================>]  17.32K  --.-KB/s    in 0.001s
#
# 2022-01-25 02:10:39 (13.2 MB/s) - ‘mashsg.py’ saved [17739/17739]
#
# --2022-01-25 02:10:39--  https://raw.githubusercontent.com/carloshvmoraes/MASHSG/main/sample/Circuito01.json?token=GHSAT0AAAAAABP4N36G2KLCPCHO7XRP5AQMYPPLRCA
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# ...

# %%
# !pip install pandapower
# !pip install networkx
# Out:
# ...
#      |████████████████████████████████| 5.8 MB 5.0 MB/s
# ...
#      |████████████████████████████████| 149 kB 46.0 MB/s
# ...
#      |████████████████████████████████| 3.6 MB 43.5 MB/s
# ...
#   Created wheel for pandapower: filename=pandapower-2.7.0-py3-none-any.whl size=5777358 sha256=6f20fed7f58b98c2d6e7e73a51b17c77cce8cc2deaa136a856950d1a1ef10708
#   Stored in directory: /root/.cache/pip/wheels/ff/e6/b6/c9218d5a45a02f4bdb220272f2bac4f59c5b73ed08a08125c3
# Successfully built pandapower
# ...

# %%
import os
from mashsg import MASHSG

print('=== Distributed Intelligent System for SelfHealing in Smart Grids ===')

mas = MASHSG(jsonNet='Circuito01.json')
mas.plot(draw_bus_id=True)
# Out:
# === Distributed Intelligent System for SelfHealing in Smart Grids ===

# %%
mas.start_simu()
mas.set_cc(load_bus_cc=9)

while mas.Step():
    print('Step',mas.t)
# Out:
# Step 1
# Step 2
# Step 3
# Step 4
# Step 5
# Step 6
# Step 7
# Step 8
# Step 9
# Step 10
# Step 11
# Step 12
# Step 13
# Step 14
# Step 15
# Step 16
# Step 17
